# %% [markdown]
# <img src="https://raw.githubusercontent.com/andre-marcos-perez/ebac-course-utils/main/media/logo/newebac_logo_black_half.png" alt="ebac-logo">
#
# ---
#
# # **Módulo** | Python: Variáveis & Tipos de Dados
# Caderno de **Exercícios**<br>
# Professor [André Perez](https://www.linkedin.com/in/andremarcosperez/)
#
# ---

# %% [markdown]
# # **Tópicos**
#
# <ol type="1">
#   <li>Introdução ao Google Colab;</li>
#   <li>Variáveis;</li>
#   <li>Números;</li>
#   <li><i>Strings;</i></li>
#   <li>Boleanos.</li>
# </ol>

# %% [markdown]
# ---

# %% [markdown]
# # **Exercícios**

# %% [markdown]
# ## 1\. Google Colab

# %% [markdown]
# Crie uma célula de código que escreva o texto "Olá mundo!", utilize o comando `print`.

# %%
print ("Olá mundo!")
# Out:
# Olá mundo!

# %% [markdown]
# Crie uma célula de texto e adicione uma imagem.

# %% [markdown]
# ![python.png](data:image/png;base64,...)

# %% [markdown]
# ---

# %% [markdown]
# ## 2\. Números

# %% [markdown]
# Preencha as células de código para preencher os valores de (A), (B) e (C) na tabela de ticket médio abaixo:
#
# <br>
#
# | Dia   | Valor Total Vendas | Qtd Total Vendas | Ticket Medio |
# |-------|--------------------|------------------|--------------|
# | 19/01 | (A)                | 3                | 320.52       |
# | 20/01 | 834.47             | (B)              | 119.21       |
# | 23/01 | 15378.12           | 5                | (C)          |

# %%
# (A)
qtv_19 = 3
tktm_19 = 320.52

vtv_19 = qtv_19 * tktm_19
print(vtv_19)
# Out:
# 961.56

# %%
# (B)
vtv_20 = 834.47
tktm_20 = 119.21

qtv_20 = vtv_20 / tktm_20
print(qtv_20)
# Out:
# 7.000000000000001

# %%
# (C)
vtv_23 = 15378.12
qtv_23 = 5

tktm_23 = vtv_23 / qtv_23
print(tktm_23)
# Out:
# 3075.6240000000003

# %% [markdown]
# Nota:
#
# vtv: Valor Total Vendas
#
# qtv: Qtd Total Vendas
#
# tktm: Ticket Medio

# %% [markdown]
# ---

# %% [markdown]
# ## 3\. Strings

# %% [markdown]
# Aplique três métodos distintos na *string* abaixo, você pode conferir alguns métodos neste [link](https://www.w3schools.com/python/python_ref_string.asp):

# %%
cancao = 'Roda mundo, roda gigante, roda moinho, roda pião.'

# %%
#Utilizando o método swapcase
print(cancao.swapcase())
# Out:
# rODA MUNDO, RODA GIGANTE, RODA MOINHO, RODA PIÃO.

# %%
#Utilizando método split
print(cancao.split())
# Out:
# ['Roda', 'mundo,', 'roda', 'gigante,', 'roda', 'moinho,', 'roda', 'pião.']

# %%
#Utilizando método upper
print(cancao.upper())
# Out:
# RODA MUNDO, RODA GIGANTE, RODA MOINHO, RODA PIÃO.

# %% [markdown]
# Extraia da string abaixo o valor da taxa **selic** na variável `selic` e o valor do **ano** na variavel `ano`. Imprima os valores na tela.

# %%
noticia = 'Selic vai a 2,75% e supera expectativas; é a primeira alta em 6 anos.'

# %%
print(noticia.split())

#Extraindo valor da taxa
valor_taxa_selic = noticia[12:17]
print("O valor da taxa é:",(valor_taxa_selic))

#Extraindo valor do ano
valor_ano = noticia[61:69]
print("O valor do ano é:",(valor_ano))
# Out:
# ['Selic', 'vai', 'a', '2,75%', 'e', 'supera', 'expectativas;', 'é', 'a', 'primeira', 'alta', 'em', '6', 'anos.']
# O valor da taxa é: 2,75%
# O valor do ano é:  6 anos.

# %% [markdown]
# ---

# %% [markdown]
# ## 4\. Booleanos

# %% [markdown]
# Utilize a tabela da verdade para responder: qual o valor da variável x?

# %%
a = False
b = True

x = not a & b
print("O valor da variável x é: ",bool(x))
# Out:
# O valor da variável x é:  True
